# %%
import matplotlib.pyplot as plt
import pandas as pd
path = 'RC_F01_01_2015_T29_09_2018.xlsx'

# %%
df = pd.read_excel(path)
df.plot(x='data', y='curs')

# %%
# Select values from '2017-01-01'
df_data = df.loc[df.data >'2017-01-01']
df_sort = df_data.sort_values(by=['curs']).reset_index(drop=True)
df_sort.loc[(round(0.01*len(df_sort)) + 1):].curs.min()
# Out:
# 55.2441
